# %% [markdown]
# # 05 RDKitで描画

# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
# Out:
# RDKit WARNING: [22:30:39] Enabling RDKit 2019.09.3 jupyter extensions

# %%
mol = Chem.MolFromSmiles("c1ccccc1")

# %%
mol

# %% [markdown]
# ## (おまけ)　ChEMBLのデータを描画
#
# ChEMBLには構造情報としてSMILESが表示されるのでそれをコピーアンドペーストしても構造の描画ができます。
#
# - [From ChEMBL](https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL941)

# %%
glvc = Chem.MolFromSmiles("CN1CCN(Cc2ccc(cc2)C(=O)Nc3ccc(C)c(Nc4nccc(n4)c5cccnc5)c3)CC1")

# %%
glvc

# %% [markdown]
# ## sdfを扱う

# %%
mols = Chem.SDMolSupplier("ch05_compounds.sdf")

# %%
len(mols)
# Out:
# 34

# %% [markdown]
# ## 複数の分子をまとめて描画する

# %%
Draw.MolsToGridImage(mols)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=600x2400 at 0x122CDD730>

# %% [markdown]
# ## (おまけ) for loopを回しながら一つずつ描画
#
# displayを利用しないと構造が表示されないことに注意

# %%
from IPython.core.display import display
for mol in mols:
    display(mol)

# %%
m1 = Chem.MolFromSmiles('COCC')

# %%
m1

# %%
suppl = Chem.SDMolSupplier('ch05_compounds.sdf')

# %%
for mol in suppl:
    print(mol.GetNumAtoms())
# Out:
# 36
# 43
# 35
# 39
# 43
# 39
# 36
# 38
# 39
# 40
# 37
# 41
# 39
# 37
# 37
# 41
# 42
# 40
# 42
# 37
# 35
# 40
# 35
# 38
# 38
# 38
# 37
# 36
# 36
# 37
# 36
# 39
# 40
# 38

# %%
mols = [x for x in suppl]

# %%
mols[0].GetNumAtoms()
# Out:
# 36

# %%
Chem.MolToSmiles(Chem.MolFromSmiles('C1=CC=CN=C1'))
# Out:
# 'c1ccncc1'
